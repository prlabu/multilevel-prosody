# %%
import prosodic

# %%
# utt = prosodic.Text("""
# Those hours, that with gentle work did frame
# The lovely gaze where every eye doth dwell,
# Will play the tyrants to the very same
# And that unfair which fairly doth excel;
# For never-resting time leads summer on
# To hideous winter, and confounds him there;
# Sap checked with frost, and lusty leaves quite gone,
# Beauty o’er-snowed and bareness every where:
# Then were not summer’s distillation left,
# A liquid prisoner pent in walls of glass,
# Beauty’s effect with beauty were bereft,
# Nor it, nor no remembrance what it was:
# But flowers distill’d, though they with winter meet,
# Leese but their show; their substance still lives sweet.
# """)

utt = prosodic.Text('buy a puppy')
utt.children[0].children[0].children[0].children[0]
# Out:
# Syllable(num=1, txt='buy', ipa="'baɪ")

# %%
# utt.show(maxlines=30, incl_phons=True)
utt.phonemes
# Out:
# PhonemeList([
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='o'),
#     Phoneme(num=3, txt='ʊ'),
#     Phoneme(num=4, txt='z'),
#     Phoneme(num=1, txt='a'),
#     Phoneme(num=2, txt='ʊ'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=4, txt='z'),
#     Phoneme(num=1, txt='a'),
#     Phoneme(num=2, txt='ʊ'),
#     Phoneme(num=1, txt='ɛː'),
#     Phoneme(num=2, txt='z'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=3, txt='t'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='æ'),
#     Phoneme(num=3, txt='t'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='ð'),
#     Phoneme(num=1, txt='ʤ'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='n'),
#     Phoneme(num=1, txt='t'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=3, txt='l'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=3, txt='k'),
#     Phoneme(num=1, txt='d'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='d'),
#     Phoneme(num=1, txt='d'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='d'),
#     Phoneme(num=1, txt='f'),
#     Phoneme(num=2, txt='r'),
#     Phoneme(num=3, txt='e'),
#     Phoneme(num=4, txt='ɪ'),
#     Phoneme(num=5, txt='m'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=1, txt='l'),
#     Phoneme(num=2, txt='ʌ'),
#     Phoneme(num=3, txt='v'),
#     Phoneme(num=1, txt='l'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=1, txt='ɡ'),
#     Phoneme(num=2, txt='e'),
#     Phoneme(num=3, txt='ɪ'),
#     Phoneme(num=4, txt='z'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='ɛ'),
#     Phoneme(num=2, txt='v'),
#     Phoneme(num=1, txt='r'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=1, txt='ɛ'),
#     Phoneme(num=1, txt='v'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=1, txt='iː'),
#     Phoneme(num=1, txt='a'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=1, txt='d'),
#     Phoneme(num=2, txt='ɔː'),
#     Phoneme(num=3, txt='θ'),
#     Phoneme(num=1, txt='d'),
#     Phoneme(num=2, txt='w'),
#     Phoneme(num=3, txt='ɛ'),
#     Phoneme(num=4, txt='l'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='l'),
#     Phoneme(num=1, txt='p'),
#     Phoneme(num=2, txt='l'),
#     Phoneme(num=3, txt='e'),
#     Phoneme(num=4, txt='ɪ'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=1, txt='t'),
#     Phoneme(num=2, txt='a'),
#     Phoneme(num=3, txt='ɪ'),
#     Phoneme(num=1, txt='r'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=3, txt='n'),
#     Phoneme(num=4, txt='t'),
#     Phoneme(num=5, txt='s'),
#     Phoneme(num=1, txt='t'),
#     Phoneme(num=2, txt='uː'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=1, txt='v'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=1, txt='r'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='e'),
#     Phoneme(num=3, txt='ɪ'),
#     Phoneme(num=4, txt='m'),
#     Phoneme(num=1, txt='æ'),
#     Phoneme(num=2, txt='n'),
#     Phoneme(num=3, txt='d'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=3, txt='t'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='æ'),
#     Phoneme(num=3, txt='t'),
#     Phoneme(num=1, txt='ə'),
#     Phoneme(num=2, txt='n'),
#     Phoneme(num=1, txt='f'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='ə'),
#     Phoneme(num=2, txt='n'),
#     Phoneme(num=1, txt='f'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='ɔː'),
#     Phoneme(num=2, txt='n'),
#     Phoneme(num=1, txt='f'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='ʧ'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='ʧ'),
#     Phoneme(num=1, txt='f'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='l'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=1, txt='d'),
#     Phoneme(num=2, txt='ɔː'),
#     Phoneme(num=3, txt='θ'),
#     Phoneme(num=1, txt='ɪ'),
#     Phoneme(num=2, txt='k'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='l'),
#     Phoneme(num=1, txt='f'),
#     Phoneme(num=2, txt='ɔː'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='n'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=1, txt='v'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=1, txt='r'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='t'),
#     Phoneme(num=3, txt='ɪ'),
#     Phoneme(num=4, txt='ŋ'),
#     Phoneme(num=1, txt='t'),
#     Phoneme(num=2, txt='a'),
#     Phoneme(num=3, txt='ɪ'),
#     Phoneme(num=4, txt='m'),
#     Phoneme(num=1, txt='l'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=3, txt='d'),
#     Phoneme(num=4, txt='z'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=1, txt='m'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=1, txt='ɑ'),
#     Phoneme(num=2, txt='n'),
#     Phoneme(num=1, txt='t'),
#     Phoneme(num=2, txt='uː'),
#     Phoneme(num=1, txt='h'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=1, txt='d'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=1, txt='ə'),
#     Phoneme(num=2, txt='s'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='n'),
#     Phoneme(num=1, txt='t'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=1, txt='æ'),
#     Phoneme(num=2, txt='n'),
#     Phoneme(num=3, txt='d'),
#     Phoneme(num=1, txt='k'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=3, txt='n'),
#     Phoneme(num=1, txt='f'),
#     Phoneme(num=2, txt='a'),
#     Phoneme(num=3, txt='ʊ'),
#     Phoneme(num=4, txt='n'),
#     Phoneme(num=5, txt='d'),
#     Phoneme(num=6, txt='z'),
#     Phoneme(num=1, txt='h'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='m'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='æ'),
#     Phoneme(num=3, txt='p'),
#     Phoneme(num=1, txt='ʧ'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='k'),
#     Phoneme(num=4, txt='t'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='ð'),
#     Phoneme(num=1, txt='f'),
#     Phoneme(num=2, txt='r'),
#     Phoneme(num=3, txt='ɔː'),
#     Phoneme(num=4, txt='s'),
#     Phoneme(num=5, txt='t'),
#     Phoneme(num=1, txt='æ'),
#     Phoneme(num=2, txt='n'),
#     Phoneme(num=3, txt='d'),
#     Phoneme(num=1, txt='l'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='t'),
#     Phoneme(num=3, txt='iː'),
#     Phoneme(num=1, txt='l'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=3, txt='v'),
#     Phoneme(num=4, txt='z'),
#     Phoneme(num=1, txt='k'),
#     Phoneme(num=2, txt='w'),
#     Phoneme(num=3, txt='a'),
#     Phoneme(num=4, txt='ɪ'),
#     Phoneme(num=5, txt='t'),
#     Phoneme(num=1, txt='ɡ'),
#     Phoneme(num=2, txt='ɔː'),
#     Phoneme(num=3, txt='n'),
#     Phoneme(num=1, txt='b'),
#     Phoneme(num=2, txt='j'),
#     Phoneme(num=3, txt='uː'),
#     Phoneme(num=1, txt='t'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=1, txt='ɔː'),
#     Phoneme(num=2, txt='r'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='n'),
#     Phoneme(num=3, txt='o'),
#     Phoneme(num=4, txt='ʊ'),
#     Phoneme(num=5, txt='d'),
#     Phoneme(num=1, txt='æ'),
#     Phoneme(num=2, txt='n'),
#     Phoneme(num=3, txt='d'),
#     Phoneme(num=1, txt='b'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='ɹ'),
#     Phoneme(num=4, txt='n'),
#     Phoneme(num=1, txt='ə'),
#     Phoneme(num=2, txt='s'),
#     Phoneme(num=1, txt='ɛ'),
#     Phoneme(num=2, txt='v'),
#     Phoneme(num=1, txt='r'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=1, txt='ɛ'),
#     Phoneme(num=1, txt='v'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=1, txt='iː'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='n'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='n'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=1, txt='n'),
#     Phoneme(num=2, txt='ɑ'),
#     Phoneme(num=3, txt='t'),
#     Phoneme(num=1, txt='n'),
#     Phoneme(num=2, txt='ɑ'),
#     Phoneme(num=3, txt='t'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=1, txt='m'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=3, txt='z'),
#     Phoneme(num=1, txt='d'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='t'),
#     Phoneme(num=3, txt='ə'),
#     Phoneme(num=1, txt='l'),
#     Phoneme(num=2, txt='e'),
#     Phoneme(num=3, txt='ɪ'),
#     Phoneme(num=1, txt='ʃ'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=3, txt='n'),
#     Phoneme(num=1, txt='l'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='f'),
#     Phoneme(num=4, txt='t'),
#     Phoneme(num=1, txt='e'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=1, txt='l'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=1, txt='k'),
#     Phoneme(num=2, txt='w'),
#     Phoneme(num=3, txt='ə'),
#     Phoneme(num=4, txt='d'),
#     Phoneme(num=1, txt='p'),
#     Phoneme(num=2, txt='r'),
#     Phoneme(num=3, txt='ɪ'),
#     Phoneme(num=4, txt='z'),
#     Phoneme(num=1, txt='n'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=1, txt='p'),
#     Phoneme(num=2, txt='r'),
#     Phoneme(num=3, txt='ɪ'),
#     Phoneme(num=1, txt='z'),
#     Phoneme(num=2, txt='ʌ'),
#     Phoneme(num=1, txt='n'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=1, txt='p'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='n'),
#     Phoneme(num=4, txt='t'),
#     Phoneme(num=1, txt='ɪ'),
#     Phoneme(num=2, txt='n'),
#     Phoneme(num=1, txt='ɪ'),
#     Phoneme(num=2, txt='n'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɔː'),
#     Phoneme(num=3, txt='l'),
#     Phoneme(num=4, txt='z'),
#     Phoneme(num=1, txt='ʌ'),
#     Phoneme(num=2, txt='v'),
#     Phoneme(num=1, txt='ɡ'),
#     Phoneme(num=2, txt='l'),
#     Phoneme(num=3, txt='æ'),
#     Phoneme(num=4, txt='s'),
#     Phoneme(num=1, txt='b'),
#     Phoneme(num=2, txt='j'),
#     Phoneme(num=3, txt='uː'),
#     Phoneme(num=1, txt='ɾ'),
#     Phoneme(num=2, txt='i'),
#     Phoneme(num=3, txt='z'),
#     Phoneme(num=1, txt='iː'),
#     Phoneme(num=1, txt='f'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='k'),
#     Phoneme(num=4, txt='t'),
#     Phoneme(num=1, txt='ɪ'),
#     Phoneme(num=1, txt='f'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='k'),
#     Phoneme(num=4, txt='t'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='ð'),
#     Phoneme(num=1, txt='b'),
#     Phoneme(num=2, txt='j'),
#     Phoneme(num=3, txt='uː'),
#     Phoneme(num=1, txt='t'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=1, txt='b'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=1, txt='ɛ'),
#     Phoneme(num=2, txt='f'),
#     Phoneme(num=3, txt='t'),
#     Phoneme(num=1, txt='n'),
#     Phoneme(num=2, txt='ɔː'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='ɪ'),
#     Phoneme(num=2, txt='t'),
#     Phoneme(num=1, txt='n'),
#     Phoneme(num=2, txt='ɔː'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='n'),
#     Phoneme(num=2, txt='o'),
#     Phoneme(num=3, txt='ʊ'),
#     Phoneme(num=1, txt='r'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=1, txt='m'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='m'),
#     Phoneme(num=1, txt='b'),
#     Phoneme(num=2, txt='r'),
#     Phoneme(num=3, txt='ə'),
#     Phoneme(num=4, txt='n'),
#     Phoneme(num=5, txt='s'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ʌ'),
#     Phoneme(num=3, txt='t'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ʌ'),
#     Phoneme(num=3, txt='t'),
#     Phoneme(num=1, txt='ɪ'),
#     Phoneme(num=2, txt='t'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɑ'),
#     Phoneme(num=3, txt='z'),
#     Phoneme(num=1, txt='b'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=3, txt='t'),
#     Phoneme(num=1, txt='f'),
#     Phoneme(num=2, txt='l'),
#     Phoneme(num=3, txt='a'),
#     Phoneme(num=4, txt='ʊ'),
#     Phoneme(num=1, txt='ɛː'),
#     Phoneme(num=2, txt='z'),
#     Phoneme(num=1, txt='d'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='s'),
#     Phoneme(num=1, txt='t'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='l'),
#     Phoneme(num=4, txt='d'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='o'),
#     Phoneme(num=3, txt='ʊ'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='e'),
#     Phoneme(num=3, txt='ɪ'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='ð'),
#     Phoneme(num=1, txt='w'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='n'),
#     Phoneme(num=1, txt='t'),
#     Phoneme(num=2, txt='ɛː'),
#     Phoneme(num=1, txt='m'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=3, txt='t'),
#     Phoneme(num=1, txt='l'),
#     Phoneme(num=2, txt='iː'),
#     Phoneme(num=3, txt='s'),
#     Phoneme(num=1, txt='b'),
#     Phoneme(num=2, txt='ə'),
#     Phoneme(num=3, txt='t'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='ʃ'),
#     Phoneme(num=2, txt='o'),
#     Phoneme(num=3, txt='ʊ'),
#     Phoneme(num=1, txt='ð'),
#     Phoneme(num=2, txt='ɛ'),
#     Phoneme(num=3, txt='r'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='ʌ'),
#     Phoneme(num=3, txt='b'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='t'),
#     Phoneme(num=3, txt='ə'),
#     Phoneme(num=4, txt='n'),
#     Phoneme(num=5, txt='s'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='t'),
#     Phoneme(num=3, txt='ɪ'),
#     Phoneme(num=4, txt='l'),
#     Phoneme(num=1, txt='l'),
#     Phoneme(num=2, txt='ɪ'),
#     Phoneme(num=3, txt='v'),
#     Phoneme(num=4, txt='z'),
#     Phoneme(num=1, txt='s'),
#     Phoneme(num=2, txt='w'),
#     Phoneme(num=3, txt='iː'),
#     Phoneme(num=4, txt='t')
#  ])
